# %%
#importing libraries for analysis and visualisation

import numpy as np #numpy for linear algebra
import pandas as pd #pandas for data manipulation and analysis
import seaborn as sns #seabirn for visualisation
import matplotlib.pyplot as plt #for visualisation

# %%
#loading our csv data file
df = pd.read_csv('insurance.csv')

# %%
#listing the first 5 rows
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#listing last 5 rows
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
#showing randow 10 sample rows
df.sample(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1081   32    male  27.835         1     no  northwest   4454.40265
# 720    51  female  40.660         0     no  northeast   9875.68040
# 1143   39    male  32.340         2     no  southeast   6338.07560
# 1026   19    male  26.030         1    yes  northwest  16450.89470
# 483    51  female  39.500         1     no  southwest   9880.06800
# 776    40    male  32.300         2     no  northwest   6986.69700
# 806    40  female  41.420         1     no  northwest  28476.73499
# 1133   52  female  18.335         0     no  northwest   9991.03765
# 1099   25  female  33.990         1     no  southeast   3227.12110
# 1293   46    male  25.745         3     no  northwest   9301.89355

# %%
#Information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#shape of the dataframe -> rows and columns (observations and variables)
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# The data has 1338 observations and 7 columns (variables)

# %%
#It gives the columns in the dataframe
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
#It provides descriptive statistics for us.
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#The describe will return statistics for numeric datatypes.For strings and timestamps, we have to use 'include = 'O' '
df.describe(include='O')
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
#It will give descriptive statistics for all datatypes
df.describe(include='all')
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.663397     1.094918    NaN        NaN
# std       14.049960   NaN     6.098187     1.205493    NaN        NaN
# min       18.000000   NaN    15.960000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.296250     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.693750     2.000000    NaN        NaN
# max       64.000000   NaN    53.130000     5.000000    NaN        NaN
#
#              charges
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean    13270.422265
# std     12110.011237
# min      1121.873900
# 25%      4740.287150
# 50%      9382.033000
# 75%     16639.912515
# max     63770.428010

# %%
#The unique method gives the unique values for the Object datatype -> sex.
df.sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
list(df.region.unique())
# Out:
# ['southwest', 'southeast', 'northwest', 'northeast']

# %%
list(df.smoker.unique())
# Out:
# ['yes', 'no']

# %%
df.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %% [raw]
# Data cleaning:
#     This step is very important because we have to analyse and visualise. For this, the data has to be clean.

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [raw]
# There are no missing values. So, we don't have to worry about any missing values.

# %% [raw]
# Checking for duplicates

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %% [raw]
# The above code will give the each rows with a boolean values. If the rows are duplicates, they are mentioned as True (They are duplicates). If they aren't, it is False.

# %%
df.duplicated(keep = 'first')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %% [raw]
# The ' keep = 'first' ' will tell the program to take the rows as duplicates except the first occurence.

# %%
df[df.duplicated(keep = 'first')]
# Out:
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %% [raw]
# The above will give the rows which are marled as True.

# %% [raw]
# Then how can we remove duplicates?

# %%
df.drop_duplicates(keep = 'first', inplace = True)

# %% [raw]
# The duplicates will be dropped from the dataframe. The attribute 'inplace = True' is important, so that it will remove the duplicates from the dataframe.

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %% [raw]
# You can see that the df has one row less than the previous one. So, if you want to delete permanently from the dataframe, use 'inplace = True'

# %% [markdown]
# **Data Visualisation**

# %%
plt.figure(figsize=(10, 10))
sns.displot(df.charges, kde = True, color = 'r')
plt.title('Charges Distribution',size=18)
plt.xlabel('Charges',size=14)
plt.ylabel('Density',size=14)
plt.show()

# %% [markdown]
# From the distribution plot, we can see that is right skewed.

# %%
plt.figure(figsize=(10, 10))
sns.displot(df.age, color = 'g', kde = True)
plt.xlabel('Age', size = 14)
plt.ylabel('Density', size = 14)
plt.title('Age distribution')
plt.show()

# %% [markdown]
# The variable 'age' is seemed to be symmetrically skewed.

# %%
plt.figure(figsize =(12, 10))
sns.histplot(df.bmi, kde = True)
plt.xlabel('BMI', size = 14)
plt.ylabel('Density', size = 14)
plt.title('BMI distributiion')
plt.show()

# %%
sns.histplot(df.charges, kde = True, color='r')
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %% [markdown]
# **Boxplot analysis**

# %%
sns.boxplot(x=df.charges)
# Out:
# <Axes: xlabel='charges'>

# %% [markdown]
# From the above boxplot, we can see that there are many outliers.
# Lets see how can we remove outliers if we want.

# %%
Q1 = df['charges'].quantile(0.25)
Q3 = df['charges'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# 11911.37345

# %%
df[(df['charges'] < Q1 - 1.5*IQR) | (df['charges'] > Q3 + 1.5*IQR) ]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 14     27    male  42.130         0    yes  southeast  39611.75770
# 19     30    male  35.300         0    yes  southwest  36837.46700
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 29     31    male  36.300         2    yes  southwest  38711.00000
# 30     22    male  35.600         0    yes  southwest  35585.57600
# ...   ...     ...     ...       ...    ...        ...          ...
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 1301   62    male  30.875         3    yes  northwest  46718.16325
# 1303   43    male  27.800         0    yes  southwest  37829.72420
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1323   42  female  40.370         2    yes  southeast  43896.37630
#
# [139 rows x 7 columns]

# %%
sns.boxplot(x=df.age)
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(x=df.bmi)
# Out:
# <Axes: xlabel='bmi'>

# %% [markdown]
# Now, we have seen univariate analysis on numerical values (continous values). Now, we will continue our univariate analysis on categorical values.

# %%
plt.figure(figsize=(5,6))
sns.countplot(x=df.sex)
plt.show()

# %% [markdown]
# From the countplot, we can see that both male and female has same count.

# %%
df.sex.value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %%
sns.countplot(x=df.children, color='y', palette='Blues')
# Out:
# C:\Users\pg900\AppData\Local\Temp\ipykernel_4384\2960781311.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df.children, color='y', palette='Blues')
# <Axes: xlabel='children', ylabel='count'>

# %%
df.children.value_counts()
# Out:
# children
# 0    573
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %% [markdown]
# From the countplot, we can see that there are more people who are with no children.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %%
sns.countplot(x=df.smoker, palette='Greens')
# Out:
# C:\Users\pg900\AppData\Local\Temp\ipykernel_4384\3232184283.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df.smoker, palette='Greens')
# <Axes: xlabel='smoker', ylabel='count'>

# %%
df.smoker.value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %% [markdown]
# There are less smokers in the dataset.

# %%
sns.countplot(x='region', data=df, palette='Reds')
# Out:
# C:\Users\pg900\AppData\Local\Temp\ipykernel_4384\454098138.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='region', data=df, palette='Reds')
# <Axes: xlabel='region', ylabel='count'>

# %% [markdown]
# We can see a equal counts in the each of the regions.

# %% [markdown]
# **Bivariate Analysis**
#
#  This analysis will be carried on only two variables.

# %% [markdown]
# 'Age vs Charges'

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x='age', y='charges', data=df, color='r')
plt.title('Age vs Charges ')
plt.show()

# %% [markdown]
# From the scatterplot, we can tell the relationship between these two variables has a weak positive correlation.
# So, if the age increases, the charges will slightly increases

# %%
print(f"The correlation co-efficient between ages and charges: {round(df['age'].corr(df['charges']), 3)}")
# Out:
# The correlation co-efficient between ages and charges: 0.298

# %% [markdown]
# The correlation co-efficient is weak positive correlation.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %%
sns.scatterplot(x='bmi', y='charges', data=df, color='b')
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
df['charges'].corr(df['bmi'])
# Out:
# 0.1984008312262494

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %%
sns.scatterplot(x='children', y='charges', data=df, color='g')
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %%
df['children'].corr(df['charges'])
# Out:
# 0.06738935083963248

# %% [markdown]
# Boxplot is normally done for categorical vs numerical values

# %% [markdown]
# Smokers vs Charges

# %%
sns.boxplot(x='smoker', y='charges', data=df, color='skyblue')
# Out:
# <Axes: xlabel='smoker', ylabel='charges'>

# %% [markdown]
# From the boxplot, we can see that the cost of insurance is higher for smokers than the non-smokers.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %% [markdown]
# Region vs Charges

# %%
sns.boxplot(x='region', y='charges', data=df, color='violet')
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %% [markdown]
# Sex vs Charges

# %%
sns.boxplot(x='sex', y='charges', data=df, color='yellow')
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
sns.pairplot(df)

# %% [markdown]
# **Multi variate Analysis**

# %%
df_numeric = df.select_dtypes(include=[float, int])
sns.heatmap(df_numeric.corr(), annot=True, square=True,
            cmap='RdBu', vmax=1, vmin=-1)
plt.show()
